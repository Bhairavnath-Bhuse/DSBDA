# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = sns.load_dataset('titanic')
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Distribution Plots

# %%
# Dist-plot

# %%
import seaborn as sns
sns.displot(x = dataset['age'], bins = 10, kde=True)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(dataset['age'], bins = 10,kde=False)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#b. Joint Plot

# %%
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind ='scatter')

# %%
sns.jointplot(x = dataset['age'], y = dataset['fare'], kind = 'hex')

# %%
#c. The Rug Plot

# %%
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# # Categorical plot

# %%
sns.barplot(x='sex', y='age', data=dataset, palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(hue='sex', y='age', data=dataset, estimator=np.std,palette=["blue", "yellow"])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# <Axes: ylabel='age'>

# %%
#b. The Count Plot

# %%
sns.countplot(x='sex', data=dataset, palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#c. The Box Plot

# %%
sns.boxplot(x='sex', y='age', data=dataset,palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age', data=dataset, hue="survived",palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#d. The Violin Plot

# %%
sns.violinplot(x='sex', y='age', data=dataset,palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset, hue='survived',palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# # Advanced Plots:

# %%
#a. The Strip Plot

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=False,palette=["blue", "yellow"])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3560\1598355155.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='sex', y='age', data=dataset, jitter=False,palette=["blue", "yellow"])
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True,palette=["blue", "yellow"])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3560\1650230823.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='sex', y='age', data=dataset, jitter=True,palette=["blue", "yellow"])
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True, hue='survived',palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
#b. The Swarm Plot

# %%
sns.swarmplot(x='sex', y='age', data=dataset,palette=["blue", "yellow"])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3560\522276610.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='sex', y='age', data=dataset,palette=["blue", "yellow"])
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x='sex', y='age', data=dataset, hue='survived',palette=["blue", "yellow"])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# # Matrix Plots

# %%
# a. Heat Map

# %%
corr = dataset.corr()
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 corr = dataset.corr()
#       2 sns.heatmap(corr)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
dataset["sex"] = pd.to_numeric(dataset["sex"])

# %%
corr = dataset.corr()
sns.heatmap(corr)

# %%
#b. Cluster Map:

# %%
sns.histplot(dataset['fare'], kde=False, bins=10)
